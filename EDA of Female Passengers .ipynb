# %% [markdown]
# # Titanic dataset

# %% [markdown]
# ## VARIABLE DESCRIPTIONS
# Pclass =  Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
#
# survived =  Survival (0 = No; 1 = Yes)
#
# Sibsp = Number of Siblings/Spouses Aboard
#
# Parch = Number of Parents/Children Aboard
#
# Ticket = Ticket Number
#
# Fare = Passenger Fare (British pound)
#
# Embarked = Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
df_org = pd.read_csv(r'D:\ML_WORK\Kaggle\Titanic\train.csv')

# %%
df = df_org[ (df_org['Sex']=='female')]

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
survived = df[df['Survived'] == 1]

# %%
Died = df[df['Survived'] == 0]

# %%
def barpieplot (data= None, x=None, width =None, height= None ):
    value_counts = data[x].value_counts() #values
    label = value_counts.index # labels

    # Pie chart
    plt.figure(figsize=(width,height))
    plt.subplot(1,2,1)
    plt.axis('equal')
    plt.pie(value_counts,labels=label, autopct='%0.2f%%',radius=1.7)
   
    plt.legend()

    # bar plot
    plt.subplot(1,2,2)
    for i,j in zip(label, value_counts):
        plt.bar(str(i),j, label= i)
    plt.legend()
    plt.xlabel(value_counts,fontsize=15)
    plt.yticks(fontsize=15)
    plt.title(x,fontsize=15)

# %% [markdown]
# ## Summury

# %%
plt.figure(figsize=(10,5))
plt.bar(df.Age.describe().index.tolist(), df.Age.describe().values.tolist())
plt.xlabel(np.round(df.Age.describe(),decimals=2),fontsize=15)
plt.show()

# %% [markdown]
# ## outlier detection

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
sns.boxplot(data=df,y='Age')
plt.title('Age')

plt.subplot(1,2,2)
sns.boxplot(data=df,y='Fare')
plt.title('Fare')

plt.show()

# %% [markdown]
# # survived = Survival (0 = No; 1 = Yes)

# %%
barpieplot(data=df, x='Survived', width=15, height=4)

# %% [markdown]
# ## Number of Females  in Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)

# %%
barpieplot(data=df, x='Pclass',width=15,height=4)

# %% [markdown]
# ##  Number of female survived as per passenger class

# %%
barpieplot(data=survived,x='Pclass',width=15,height=4)

# %% [markdown]
# ## Number of Female not survived as per passenger class

# %%
barpieplot(data=Died,x='Pclass',width=15,height=4)

# %% [markdown]
# * Most of the females died belongs to 3rd classs of passenger class

# %% [markdown]
# ## Females Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)

# %%
barpieplot(data=df,x='Embarked',width=15,height=4)

# %% [markdown]
# * Emabakation of females from Southampton is significantly high

# %% [markdown]
# ## Survival of Females as per their port of embarkation

# %%
barpieplot(data=survived,x='Embarked',width=15,height=4)

# %% [markdown]
# ##  Females not survived as per their port of embarkation

# %%
barpieplot(data=Died,x='Embarked',width=15,height=4)

# %% [markdown]
# ## Number of Siblings/Spouses Aboard

# %%
barpieplot(data=df,x='SibSp',width=15,height=4)

# %% [markdown]
# ## survived

# %%
barpieplot(data=survived,x='SibSp',width=15,height=4)

# %% [markdown]
# ## Not survived

# %%
barpieplot(data=Died,x='SibSp',width=15,height=4)

# %% [markdown]
# # Parch = Number of Parents/Children Aboard

# %%
barpieplot(data=df,x='Parch',width=15,height=4)

# %% [markdown]
# ## survived

# %%
barpieplot(data=survived,x='Parch',width=15,height=4)

# %% [markdown]
# # Not survived

# %%
barpieplot(data=Died,x='Parch',width=15,height=4)

# %% [markdown]
# ## Port of embarkation and passenger class

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=df,x='Pclass',hue='Embarked')
plt.show()
